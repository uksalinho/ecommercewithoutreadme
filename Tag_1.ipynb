# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# print fonksiyonun parantezsiz kullanımında hata alırız (python 3.x ve üstü için )
#
# ---
#
#
# Hangi tırnak ile başladıysak o tırnakla sonlandırmalıyız!

# %%
 print('''Eyyup  
           Oguzhan
            Uksal''') 
 print("""Eyyup
           Oguzhan
            Uksal""") # Birden fazla satira yazilan mesaj icin "" böyle basla bitir olmaz. Hata mesaji verir.
# Out:
# Eyyup
#           Oguzhan
#            Uksal
# Eyyup
#           Oguzhan
#            Uksal

# %%
print("Eyyup \n Oguzhan \n  Uksal") # Cift tirnak ile yukaridaki gibi yazmak icin  \n kullandim
# Out:
# Eyyup
#  Oguzhan
#   Uksal

# %%
 print('Eyyup Oguzhan \
     Uksal') # Coook uzun bir kod yazdim ama ciktisini tek satirda istiyorum \ ile. 
     # Bir satira en fazla 79 karakterlik KOD yazabilirim. 
     # En fazla 72 karakterlik aciklama yapabilirim.
# Out:
# Eyyup Oguzhan     Uksal

# %%
print("I'm Oguzhan")
# print('I'm Oguzhan') basladigimla bitirdim ama arada aynisindan var. Bu yüzden hata verir.
# '...' veya '''...''' olur ama ''...'' olmaz. Iki tek tirnak cift tirnaga benziyor hata veriyor.
# Out:
# I'm Oguzhan

# %%
print('3.14' + '1.0') # Iki sitring ifadeyi yanyana yazdi
print(3.14 + 1.0) # Toplama yapti
# Out:
# 3.141.0
# 4.140000000000001

# %%
print(''''En büyük FENERBAHCE"''') # Hata vermedi 3 adet ' ile basladi ve bitti. Digerlerini de yazdi
# Out:
# 'En büyük FENERBAHCE"

# %%
print('SAMPIYON') # Satirlar arasinda bosluk birakmak icin hepsini kullanabilirim
print()
print('')
print("")            
print("FENERBAHCE")  # Yorum yaparken koddan sonra 2 bosluk, #sonra 1 bosluk ve büyükharfle basla
# Out:
# SAMPIYON
#
#
#
# FENERBAHCE

# %% [markdown]
# Print ifadenin sonuna bir karakter basmak istersem end=' '.
# Print icindeki ifadeler varsayilan olarak bosluk birakiyor ama sep=' ' yazarsam bosluk yerine baska bir sey olur.
# Print ifade normalde ekrana yazdiriyor ama ekrana degilde dosyaya yazdir dersem 'file='

# %%
print("Eyyup", "Oguzhan", "Uksal", sep='&', end='***')
# Out:
# Eyyup&Oguzhan&Uksal***

# %%
print('Eyyup\tOguzhan\tUksal') # \t bir tab bosluk birak yani genellikle 4 space demek
# Out:
# Eyyup	Oguzhan	Uksal

# %%
print('Oguzhan \'Cabuk is bulur muyuz?\' diye sordu') # Satir 18deki hatayi vermemesi icin \ kullandim
# Out:
# Oguzhan 'Cabuk is bulur muyuz?' diye sordu

# %%
print("Hoca 9\\3=3 dedi")
print("Hoca 9\3=3 dedi") # Böyle yazinca yanlis yazdirdi
# Out:
# Hoca 9\3=3 dedi
# Hoca 9=3 dedi

# %%
import this #PEP 20 de PEP8 gibi bir yazim felsefesidir
